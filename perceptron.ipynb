# %%
from perceptron import Perceptron

import matplotlib.pyplot as plt
from seaborn import lineplot

# %%
inputs = np.array([[-1, -1],
                   [-1, 1],
                   [1, -1],
                   [1, 1]])

output = np.array([[-1],
                   [-1],
                   [-1],
                   [1]])

bias = np.random.normal()

# %%
plt.scatter(x=inputs[:, 0], y=inputs[:, 1], c=output, cmap='autumn')

# %%
weights = np.random.normal(size=2)
bias = np.random.normal()
lr = 0.2
EPOCHS = 10

perceptron = Perceptron(inputs=inputs, 
                        outputs=output, 
                        learning_rate=lr, 
                        activation_function=lambda x: -1 if x <= 0 else 1)

weights, epsilons = perceptron.train(EPOCHS)
lineplot(epsilon)
print(perceptron.predict(np.array([1, -1])))
# Out:
# -1
